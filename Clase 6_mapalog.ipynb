# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import matplotlib as mpl
label_size = 14
mpl.rcParams['xtick.labelsize'] = label_size 
mpl.rcParams['ytick.labelsize'] = label_size

# %%
r = 1
def poblacion(x, t):
    return r * x * (1 - x)

# %%
x0 = 0.05
tt = np.linspace(0, 10)
xx = odeint(poblacion, x0, tt)
plt.plot(tt, xx)
plt.xlabel('$t$', fontsize = 18)
plt.ylabel('$x$', fontsize = 18)
plt.show()

# %%
def logi_sol(t, x0, r):
    return 1/(1 + (1/x0 - 1) * np.exp(-r * t))

# %%
t = np.linspace(0,10)
for r in np.arange(-1, 1,.1):
    plt.plot(t, logi_sol(t, 0.05, r))
plt.xlabel('$t$', fontsize = 18)
plt.ylabel('$x$', fontsize = 18)
plt.show()

# %%
import numpy as np
def mapa_logistico(r, x):
    return r * x * (1 - x)

# %%
# Para mil valores de r entre 2.5 y 4.0
n = 1000
r = np.linspace(.5, 4.0, n)

# %%
plt.figure(figsize=(7, 4.5))
for i in range(iterar):
    x = mapa_logistico(r, x)
    if i >= (iterar - ultimos):
        plt.plot(r, x, ',k', alpha=.2)
plt.xlim(.4, 4)
plt.ylim(-.1, 1.1)
plt.title("Diagrama de bifurcación")
plt.xlabel('$r$', fontsize=18)
plt.ylabel('$x$', fontsize=18)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-a90e1a4e3857> in <module>()
#       1
#       2 plt.figure(figsize=(7, 4.5))
# ----> 3 for i in range(iterar):
#       4     x = mapa_logistico(r, x)
#       5     if i >= (iterar - ultimos):
#
# NameError: name 'iterar' is not defined

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharex='col', sharey='row',figsize =(13,4.5))
r = np.linspace(.5, 4.0, n)
for i in range(iterar):
    x = mapa_logistico(r, x)
    if i >= (iterar - ultimos):
        ax1.plot(r, x, '.k', alpha=1,  ms = .1)
r = np.linspace(2.5, 4.0, n)
for i in range(iterar):
    x = mapa_logistico(r, x)
    if i >= (iterar - ultimos):
        ax2.plot(r, x, '.k', alpha=1, ms = .1)
ax1.set_xlim(.4, 4)
ax1.set_ylim(-.1, 1.1)
ax2.set_xlim(2.5, 4)
ax2.set_ylim(-.1, 1.1)
ax1.set_ylabel('$x$', fontsize = 20)
ax1.set_xlabel('$r$', fontsize = 20)
ax2.set_xlabel('$r$', fontsize = 20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-3806a6d1d5ed> in <module>()
#       1 fig, (ax1, ax2) = plt.subplots(1, 2, sharex='col', sharey='row',figsize =(13,4.5))
#       2 r = np.linspace(.5, 4.0, n)
# ----> 3 for i in range(iterar):
#       4     x = mapa_logistico(r, x)
#       5     if i >= (iterar - ultimos):
#
# NameError: name 'iterar' is not defined

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import matplotlib as mpl
label_size = 14
mpl.rcParams ['xtick.labelsize'] = label_size
mpl.rcParams ['ytick.labelsize'] = label_size

# %%
r = 1
def poblacion(P, t):
    return 2 * P

# %%
x0=10
tt = np.linspace(0, 20)
xx = odeint(poblacion, x0, tt)
plt.plot(tt,xx)
plt.xlabel('$t$', fontsize = 18)
plt.ylabel('$t$', fontsize = 18)
plt.show()

# %%
def log_sol(t, x0, r):
    return 10* np.exp(2*t)

# %%
t= np.linspace(0,20)
for r in np.arange (-1, 1, .1):
    xx = odeint(poblacion,x0, tt)
    plt.plot(t, xx)
plt.xlabel('$t$', fontsize=18)
plt.ylabel('$t$', fontsize=18)
plt.show()
