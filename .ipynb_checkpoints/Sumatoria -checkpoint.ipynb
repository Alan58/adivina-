# %%
N=int (input("Da un numero "))
M= int (input("Da el segundo numero ")) +1
suma=0
for suma in range (N,M):
    suma=suma+1
print(suma)
# Out:
# Da un numero 0
# Da el segundo numero 3
# 4

# %%
# %matplotlib inline

# %%
import numpy as np 
import matplotlib.pylab as plt

# %%
x=np.arange (1,10,1)
y = x**2

# %%
plt.plot(x,y)

# %%
# %matplotlib inline 
import numpy as np 
import matplotlib.pylab as plt
x=np.arange (0,1000,1)
y = 100*(((x**2)+(10*x)+(100))/((x**2)+(20*x)+(100)))
plt.plot(x,y)
