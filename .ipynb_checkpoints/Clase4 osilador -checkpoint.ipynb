# %% [markdown]
# $x(t)= A\cos(w_0T)+ B\sin(w_0t)$
# $x(t)= \omega_0[-A\sin(\omega_0 t) + B \cos(\omega_0t)]$

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.arange(0,10,1)
y=x**2
plt.plot(x,y)

# %%
import matplotlib as mpl
label_size= 14
mpl.rcParams["xtick.labelsize"]= label_size
mpl.rcParams["ytick.labelsize"]= label_size

# %% [markdown]
# $$x(t)= A\cos(w_0T)+ B\sin(w_0t)$$
# $$\dot x(t)= \omega_0[-A\sin(\omega_0 t) + B \cos(\omega_0t)]$$

# %%
import numpy as np

# %%
plt.plot?

# %%
t= np.linspace (0,50,100)
plt.figure(figsize=(7,4))
plt.plot(t, .5*np.cos(.5 *t) + .1 * np.sin(.5 *t), '-', lw=1, ms=4,
        label= '$x(t)$')
plt.plot(t, .5*.1*np.cos(.5*t) - .5*.5* np.sin(.5*t) , 'yo-', lw=1, ms=4,
        label= r'$\dot{x(t)}$')
plt.xlabel('$t$', fontsize=20)
plt.show()

# %%
a=2
w=0.5
b=0.1
t= np.linspace (0,500,1000)
plt.figure(figsize=(7,4))
plt.scatter(t, a*np.cos(.5 *t) + b * np.sin(w *t), lw=0, c='red',
        label= '$x(t)$')
plt.plot(t, b*w*np.cos(.5*t) - a*w* np.sin(w*t) , 'yo-', lw=1, ms=4,
        label= r'$\dot{x(t)}$')
plt.xlabel('$t$', fontsize=20)
plt.legend(loc='best')
plt.show()

# %%
A=
W=
B=
frecuencias=np.array([.1,.2,.5,.6])
plt.figure(figsize=(7, 4))
for f in frecuencias:
    plt.plot(t, )

# %%
from ipywidgets import *
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np

# %%
def masa_resorte(t = 0):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(.5 * np.cos(.5 * t) + .1 * np.sin(.5 * t), [0],  'ko', ms = 10)
    ax.set_xlim(xmin = -0.6, xmax = .6)
    ax.axvline(x=0, color = 'r')
    ax.axhline(y=0, color = 'grey', lw = 1)
    fig.canvas.draw()
interact_manual(masa_resorte, t = (0, 50,.01));

# %%
from ipywidgets import *
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np

# %%
def theta_t(a, b, g, l, t):
    omega_0 = np.sqrt(g/l)
    return a * np.cos(omega_0 * t) + b * np.sin(omega_0 * t)

# %%
def pendulo_simple(t = 0):
    fig = plt.figure(figsize = (5,5))
    ax = fig.add_subplot(1, 1, 1)
    x = 2 * np.sin(theta_t(.4, .6, 9.8, 2, t))
    y =  - 2 * np.cos(theta_t(.4, .6, 9.8, 2, t))
    ax.plot(x, y, 'ko', ms = 10)
    ax.plot([0], [0], 'rD')
    ax.plot([0, x ], [0, y], 'k-', lw = 1)
    ax.set_xlim(xmin = -2.2, xmax = 2.2)
    ax.set_ylim(ymin = -2.2, ymax = .2)
    fig.canvas.draw()
interact_manual(pendulo_simple, t = (0, 10,.01));
