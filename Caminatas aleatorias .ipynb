# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt 
import random

# %%
X_0= 0  #inicia el caminador 
elements=[1,-1]
probabilitis = [0.8,0.2]
delta_X= np.random.choice(elements,1000,probabilitis)
y = np.ones(len(np.cumsum(delta_X)))
#plt.plot( np.cumsum(delta_X),y)
plt.plot( np.cumsum(delta_X),)

# %%
plt.plot(np.cumsum(delta_X))
plt.xlabel ("Tiempo")
plt.ylabel("Distancia")

# %%
def walker():
    global x,y
    eleccion = random.randint(0,3)
    if eleccion == 0:
        x+=1
    elif eleccion ==1:
        x-=1
    elif eleccion ==2:
        y+=1
    else:
        y-=1
    return [x,y]

x=0
y=0

Pos = np.zeros((2,10))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i] = walker()
plt.plot(Pos[0,:], Pos[1,:],"bo-")
plt.plot(Pos[0,-1], Pos[1,-1],"ro-")

# %%
def walker():
    global x,y
    x +=random.randint(-1,1)
    y +=random.randint(-1,1)
    return [x,y]

x=0
y=0

Pos = np.zeros((2,1000))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i] = walker()
plt.plot(Pos[0,:], Pos[1,:],"bo-")
plt.plot(Pos[0,-1], Pos[1,-1],"ro-")

# %%
def walker():
    global x,y
    x +=random.uniform(-1,1)
    y +=random.uniform(-1,1)
    return [x,y]

x=0
y=0

Pos = np.zeros((2,1000))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i] = walker()
plt.plot(Pos[0,:], Pos[1,:],"bo-")
plt.plot(Pos[0,-1], Pos[1,-1],"ro-")

# %%
X_0= np.array([[0],[0]])
delta_X = np.random.uniform(-1,1,(2,100))

X= np.concatenate( (X_0,np.cumsum(delta_X,axis=1)),axis=1 )
rw = plt.plot(X[0] ,X[1], "ro-")

# %%
plt.hist (np.random.normal(0,1,(1000,1)));

# %%
def walker():
    global x,y
    eleccion = random.randint(0,3)
    if eleccion < 0.40:
        x+=1
    elif eleccion <0.60:
        x-=1
    elif eleccion <0.8:
        y+=1
    else:
        y-=1
    return [x,y]

x=0
y=0

Pos = np.zeros((2,1000))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i] = walker()
plt.plot(Pos[0,:], Pos[1,:],"bo-")
plt.plot(Pos[0,-1], Pos[1,-1],"ro-")

# %%
def walker():
    global x,y
    eleccion = random.randint(0,3)
    if eleccion < 0.10:
        x+=1
    elif eleccion <0.20:
        x-=1
    elif eleccion <0.1:
        y+=1
    else:
        y-=1
    return [x,y]

x=0
y=0

Pos = np.zeros((2,100))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i] = walker()
plt.plot(Pos[0,:], Pos[1,:],"bo-")
plt.plot(Pos[0,-1], Pos[1,-1],"ro-")

# %%
def walker():
    global x,y
    x +=np.random.normal(0,2000)
    y +=random.gauss(0,2000)
    return [x,y]

x=0
y=0

Pos = np.zeros((2,100))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i] = walker()
plt.plot(Pos[0,:], Pos[1,:],"bo-")
plt.plot(Pos[0,-1], Pos[1,-1],"ro-")

# %%
def walker():
    global x,y
    r= random.uniform(0,1)
    if r<0.01: 
        x += np.random.normal(0,200)
        y += random.gauss(0,200)
  
    else:
        x += np.random.normal(0,1)
        y += random.gauss(0,1)
    return [x,y]

x=0
y=0

Pos = np.zeros((2,1000))

for i in np.arange(0,len(Pos[0]),1):
    Pos[:,i] = walker()
plt.plot(Pos[0,:], Pos[1,:],"bo-")
plt.plot(Pos[0,-1], Pos[1,-1],"ro-")

# %%
inicio =np.array([ [0],[0] ] )
elements = np.array([[1,-1,0,0],[0,0,1,-1]])
probabilites= [0.4, 0.2,0.2,0.2]
pasos=elements[:,np.random.choice(elements.shape[1], 100000,p=probabilites)]
pasos=np.concatenate((inicio,pasos),axis=1)

pos=np.cumsum(pasos, axis=1 )
plt.plot(pos[0,:],pos[1,:],"bo-")

# %%
from sympy import *
import pandas as pd
var("x,t")
plot(sin(x),(x,0,pi))
integrate (sin(x),(x,0,pi))
# Out:
# 2
